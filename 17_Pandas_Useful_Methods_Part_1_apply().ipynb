# %% [markdown]
# <a href="https://colab.research.google.com/github/ThivyaTS/python-class-projects/blob/main/17_Pandas_Useful_Methods_Part_1_apply().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. .apply() method
#
# - Allows you to `apply and broadcast custom function` on a dataframe column.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df["CC Number"]
# Out:
# 0      3.560330e+15
# 1      4.478070e+15
# 2      6.011810e+15
# 3      4.676140e+15
# 4      4.832730e+15
#            ...
# 239    5.296070e+15
# 240    3.506810e+15
# 241    6.011890e+15
# 242    4.375220e+12
# 243    3.511450e+15
# Name: CC Number, Length: 244, dtype: float64

# %%
df['CC Number'].dtype
# Out:
# dtype('float64')

# %%
df['CC Number'][0]
# Out:
# 3560330000000000.0

# %%
number = 3560330000000000.0

print(number)
print(int(number))
# Out:
# 3560330000000000.0
# 3560330000000000

# %%
df['CC Number'] = df['CC Number'].astype(int)

df['CC Number']
# Out:
# 0      3560330000000000
# 1      4478070000000000
# 2      6011810000000000
# 3      4676140000000000
# 4      4832730000000000
#              ...
# 239    5296070000000000
# 240    3506810000000000
# 241    6011890000000000
# 242       4375220000000
# 243    3511450000000000
# Name: CC Number, Length: 244, dtype: int64

# %%
df['CC Number'].dtype
# Out:
# dtype('int64')

# %%
str1 = 'Beautiful'

print(str1[0:4])
# Out:
# Beau

# %%
num1 = 4375220000000

print(num1[0:4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8d0468b7586a> in <cell line: 3>()
#       1 num1 = 4375220000000
#       2
# ----> 3 print(num1[0:4])
#
# TypeError: 'int' object is not subscriptable

# %%
print(str(num1[0:4]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e17e27a3dbb8> in <cell line: 1>()
# ----> 1 print(str(num1[0:4]))
#
# TypeError: 'int' object is not subscriptable

# %%
print(str(num1)[0:4])
# Out:
# 4375

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560330000000000    Sun2959
# 1      Douglas Tucker  4478070000000000    Sun4608
# 2      Travis Walters  6011810000000000    Sun4458
# 3    Nathaniel Harris  4676140000000000    Sun5260
# 4        Tonya Carter  4832730000000000    Sun2251

# %%
def first_four(num):
  return str(num)[0:4]

# %%
df['First Four'] = df['CC Number'].apply(first_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID First Four
# ...

# %%
name1 = "John Doe"

print(name1[5:])
# Out:
# Doe

# %%
name2 = "Michelle Hardin"

print(name2[5:])
# Out:
# lle Hardin

# %%
name1 = "John Doe"

print(name1.split())
# Out:
# ['John', 'Doe']

# %%
print(name1.split()[-1])
# Out:
# Doe

# %%
name3 = "Wendy Doe Roger"

print(name3.split()[-1])
# Out:
# Roger

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID First Four
# 0  Christy Cunningham  3560330000000000    Sun2959       3560
# 1      Douglas Tucker  4478070000000000    Sun4608       4478
# 2      Travis Walters  6011810000000000    Sun4458       6011
# 3    Nathaniel Harris  4676140000000000    Sun5260       4676
# 4        Tonya Carter  4832730000000000    Sun2251       4832

# %%
def extract_last_name(name):
  return name.split()[-1]

# %%
df['Last Name'] = df['Payer Name'].apply(extract_last_name)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...
